# %% [markdown]
# CPS349
# Claire Summers
# ## Homework 1

# %%
##Task 1: Arithmetic and Variable Assignment##
radius = 5
pi = 3.14159

area = pi * radius ** 2

print(area)
# Out:
# 78.53975

# %%
##Task 2: List Manipulation and Slicing ##
colors = ["red","blue","green", "yellow", "purple"]
print(colors[2])

print(colors[0:3])

colors[3] = "gold"
print(colors)
print(len(colors))
# Out:
# green
# ['red', 'blue', 'green']
# ['red', 'blue', 'green', 'gold', 'purple']
# 5

# %%
##Task 3: Loops and Conditionals ##


for i in range(1,11):
  if i%2 == 0:
      print("even")
  else :
      print("odd")
# Out:
# odd
# even
# odd
# even
# odd
# even
# odd
# even
# odd
# even

# %%
## Task 4: Creating a Function ##
def celsius_to_fahrenheit(celsius):
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit
print(celsius_to_fahrenheit(25))
# Out:
# 77.0

# %%
## Task 5: Basic Data Visualization (Matplotlib) ##
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)

plt.title("Square Numbers")
plt.xlabel("values")
plt.ylabel("squares")

plt.show()
