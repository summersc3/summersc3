# %% [markdown]
# # Homework 2
# Claire Summers

# %% [markdown]
# ### Question 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pandas

# %%
# %cd /content/drive/MyDrive/EGR270/
# %cd practice
# !wget https://raw.githubusercontent.com/VSZM/ELTE_Adatbanyaszat_es_Gepi_tanulas/master/practice/fuel_data.txt
# Out:
# /content/drive/MyDrive/EGR270
# /content/drive/MyDrive/EGR270/practice
# --2026-02-17 20:14:07--  https://raw.githubusercontent.com/VSZM/ELTE_Adatbanyaszat_es_Gepi_tanulas/master/practice/fuel_data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8222 (8.0K) [text/plain]
# Saving to: ‘fuel_data.txt.5’
#
# fuel_data.txt.5     100%[===================>]   8.03K  --.-KB/s    in 0.008s
#
# 2026-02-17 20:14:07 (1.02 MB/s) - ‘fuel_data.txt.5’ saved [8222/8222]

# %%
import pandas as pd

# %%
df = pd.read_csv('fuel_data.txt', delimiter='\t')

# %% [markdown]
# ### Question 2

# %%
df.head(41)
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  \
# 0   2018.06.03     00:03   01:16         17       15             off
# 1   2018.06.03     08:20   09:29         19       24             off
# 2   2018.06.03     13:00   15:00         30       28              on
# 3   2018.06.04     15:30   16:30         29       28              on
# 4   2018.06.04     18:18   19:10         30       25              on
# 5   2018.06.05     21:04   22:20         25       25             off
# 6   2018.06.07     10:48   11:36         18       24             off
# 7   2018.06.07     15:22   16:25         31       26              on
# 8   2018.06.08     21:25   22:28         24       22             off
# 9   2018.06.10     17:11   18:38         30       24              on
# 10  2018.06.10     20:48   22:05         23       22             off
# 11  2018.06.11     11:11   11:47         25       27             off
# 12  2018.06.11     13:32   14:14         29       29              on
# ...

# %% [markdown]
# ### Question 3

# %%
df['tempdiff'] = df['endtemp'] - df['starttemp']

df.loc[df['tempdiff'] == df['tempdiff'].min()]
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner trafic  \
# 86  2018.08.27     17:27   19:19         28       19              on   high
#
#       route  dist  avg.cons.  speed duration fuel type     road  num. persons  \
# 86  bp-dujv  71.8        6.6     38    01:52       95+  highway             1
#
#     tempdiff
# 86        -9

# %% [markdown]
# ### Question 4

# %%
df['normalized_route'] = df['route'].apply(lambda x: '-'.join(sorted(x.split('-'))))
df
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0   2018.06.03     00:03   01:16         17       15             off     low
# 1   2018.06.03     08:20   09:29         19       24             off     low
# 2   2018.06.03     13:00   15:00         30       28              on  normal
# 3   2018.06.04     15:30   16:30         29       28              on  normal
# 4   2018.06.04     18:18   19:10         30       25              on  normal
# ..         ...       ...     ...        ...      ...             ...     ...
# 95  2018.09.03     22:00   22:55         21       19             off  normal
# 96  2018.09.04     06:42   07:55         16       17             off  normal
# 97  2018.09.04     20:00   21:10         17       16             off     low
# 98  2018.09.05     08:15   09:25         15       20             off  normal
# 99  2018.09.05     20:50   21:52         21       19             off     low
#
# ...

# %% [markdown]
# ### Question 5

# %%
df['Destination'] = df['route'].apply(lambda x: x.split('-')[1])
print(df['Destination'].value_counts().idxmax())
# Out:
# dujv

# %% [markdown]
# ### Question 6

# %%
df['avg_duration'] = df['duration'].apply(lambda x: x.split('-')[0])
df
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0   2018.06.03     00:03   01:16         17       15             off     low
# 1   2018.06.03     08:20   09:29         19       24             off     low
# 2   2018.06.03     13:00   15:00         30       28              on  normal
# 3   2018.06.04     15:30   16:30         29       28              on  normal
# 4   2018.06.04     18:18   19:10         30       25              on  normal
# ..         ...       ...     ...        ...      ...             ...     ...
# 95  2018.09.03     22:00   22:55         21       19             off  normal
# 96  2018.09.04     06:42   07:55         16       17             off  normal
# 97  2018.09.04     20:00   21:10         17       16             off     low
# 98  2018.09.05     08:15   09:25         15       20             off  normal
# 99  2018.09.05     20:50   21:52         21       19             off     low
#
# ...

# %% [markdown]
# ### Question 7

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y.%m.%d')
df['month'] = df['date'].dt.month
highest_speed = df.loc[df['speed'].idxmax()]
month_highest_speed = highest_speed['date'].month

print(month_highest_speed)
# Out:
# 8
